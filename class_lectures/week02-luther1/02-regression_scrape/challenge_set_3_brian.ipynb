# %% [markdown]
# Topic:        Challenge Set 3
#
# Subject:      Pandas Challenges
#
# Date:         1/22/2018
#
# Name:         Brian Kim
#
# Worked with:  Sungwan Kim

# %%
import numpy as np
import pandas as pd

from sklearn import linear_model, datasets
import statsmodels.api as sm
# %matplotlib inline
import matplotlib.pyplot as pyplot

from matplotlib import pyplot as plt

# %%
df = pd.read_csv("~/nyc18_ds14/challenges/challenges_data/2013_movies.csv")

# %%
##Preliminary data cleaning
##rename columns, shorten values that appear in millions; 
df.columns = df.columns.str.lower()
df['gross'] = df['domestictotalgross']
df.releasedate = pd.to_datetime(df.releasedate)#.dt.strftime('%m/%d')
df['m_budget'] = df['budget'] * .000001
df['gross_in_millions'] = df['domestictotalgross'] * .000001

# %%
df.drop(['budget'], axis = 1, inplace = True)

# %% [markdown]
# **Challenge 1**
#
# Plot domestic total gross over time.

# %%
df.set_index('releasedate').plot(y='gross_in_millions',\
                                 title ="Total Gross 2013" )

# %% [markdown]
# **Challenge 2**
#
# Plot runtime vs. domestic total gross.

# %%
df.plot(kind = 'scatter', x= 'gross_in_millions',\
        y = 'runtime',title="Total Domestic Gross")

# %%
df.plot(kind = 'scatter', x= 'runtime', y = 'gross_in_millions',\
        title="Total Domestic Gross(axes switched)")

# %% [markdown]
# **Challenge 3**
#
# Group your data by Rating and find the average runtime and domestic total gross at each level of Rating.
#    ** There was only one G rated movie in dataset and therefore did not plot. **

# %%
df.groupby(['rating'])[['runtime', 'gross_in_millions']].mean().round(2)
# Out:
#         runtime  gross_in_millions
# rating
# G        107.00             268.49
# PG        99.93             131.14
# PG-13    117.51             111.45
# R        110.73              69.89

# %%
df.rating.value_counts()
# Out:
# PG-13    47
# R        37
# PG       15
# G         1
# Name: rating, dtype: int64

# %% [markdown]
# **Challenge 4**
#
# Make one figure with (N=the number of MPAA ratings there are) subplots, and in each plot the release date vs the domestic total gross.

# %%
df.reset_index
# Out:
# <bound method DataFrame.reset_index of                                     title  domestictotalgross  \
# 0         The Hunger Games: Catching Fire           424668047
# 1                              Iron Man 3           409013994
# 2                                  Frozen           400738009
# 3                         Despicable Me 2           368061265
# 4                            Man of Steel           291045518
# 5                                 Gravity           274092705
# 6                     Monsters University           268492764
# 7     The Hobbit: The Desolation of Smaug           258366855
# 8                        Fast & Furious 6           238679850
# 9               Oz The Great and Powerful           234911825
# 10                Star Trek Into Darkness           228778661
# 11                   Thor: The Dark World           206362140
# 12                            World War Z           202359711
# 13                             The Croods           187168425
# 14                               The Heat           159582188
# 15                      We're the Millers           150394119
# 16                        American Hustle           150117807
# 17                       The Great Gatsby           144840419
# 18                          The Conjuring           137400141
# 19                         Identity Thief           134506920
# 20                            Grown Ups 2           133668525
# 21                          The Wolverine           132556852
# 22      Anchorman 2: The Legend Continues           125168368
# 23                          Lone Survivor           125095601
# 24                  G.I. Joe: Retaliation           122523060
# 25    Cloudy with a Chance of Meatballs 2           119793567
# 26                         Now You See Me           117723989
# 27                The Wolf of Wall Street           116900694
# 28                Lee Daniels' The Butler           116632095
# 29                  The Hangover Part III           112200072
# ..                                    ...                 ...
# 70                         Gangster Squad            46000903
# 71                       Jurassic Park 3D            45385935
# 72                         The Internship            44672764
# 73              Instructions Not Included            44467206
# 74                                 Snitch            42930462
# 75                                Riddick            42025135
# 76                        A Haunted House            40041683
# 77                               47 Ronin            38362475
# 78                   August: Osage County            37738810
# 79                              Philomena            37709979
# 80                             The Family            36918811
# 81                 Walking with Dinosaurs            36076121
# 82                                 Carrie            35266619
# 83                      Texas Chainsaw 3D            34341945
# 84                               R.I.P.D.            33618855
# 85                           Blue Jasmine            33405481
# 86             Kevin Hart: Let Me Explain            32244051
# 87                           Side Effects            32172757
# 88                          Scary Movie 5            32015787
# 89  The Mortal Instruments: City of Bones            31165421
# 90                           Delivery Man            30664106
# 91                           Grudge Match            29807260
# 92              One Direction: This is Us            28873374
# 93                             Kick-Ass 2            28795985
# 94                     Dallas Buyers Club            27298285
# 95                                   Rush            26947624
# 96                               The Host            26627201
# 97                        The World's End            26004851
# 98                            21 and Over            25682380
# 99                                    Her            25568251
#
#                       director rating  runtime releasedate      gross  \
# 0             Francis Lawrence  PG-13      146  2013-11-22  424668047
# 1                  Shane Black  PG-13      129  2013-05-03  409013994
# 2       Chris BuckJennifer Lee     PG      108  2013-11-22  400738009
# 3    Pierre CoffinChris Renaud     PG       98  2013-07-03  368061265
# 4                  Zack Snyder  PG-13      143  2013-06-14  291045518
# 5               Alfonso Cuaron  PG-13       91  2013-10-04  274092705
# 6                  Dan Scanlon      G      107  2013-06-21  268492764
# 7                Peter Jackson  PG-13      161  2013-12-13  258366855
# 8                   Justin Lin  PG-13      130  2013-05-24  238679850
# 9                    Sam Raimi     PG      127  2013-03-08  234911825
# 10                 J.J. Abrams  PG-13      123  2013-05-16  228778661
# 11                 Alan Taylor  PG-13      120  2013-11-08  206362140
# 12                Marc Forster  PG-13      116  2013-06-21  202359711
# 13  Kirk De MiccoChris Sanders     PG       98  2013-03-22  187168425
# 14                   Paul Feig      R      117  2013-06-28  159582188
# 15     Rawson Marshall Thurber      R      110  2013-08-07  150394119
# 16            David O. Russell      R      138  2013-12-13  150117807
# 17                Baz Luhrmann  PG-13      143  2013-05-10  144840419
# 18                   James Wan      R      112  2013-07-19  137400141
# 19                 Seth Gordon      R      111  2013-02-08  134506920
# 20                Dennis Dugan  PG-13      101  2013-07-12  133668525
# 21               James Mangold  PG-13      126  2013-07-26  132556852
# 22                  Adam McKay  PG-13      119  2013-12-18  125168368
# 23                  Peter Berg      R      121  2013-12-25  125095601
# 24                     Jon Chu  PG-13       99  2013-03-28  122523060
# 25                         NaN     PG       95  2013-09-27  119793567
# 26             Louis Leterrier  PG-13      116  2013-05-31  117723989
# 27             Martin Scorsese      R      180  2013-12-25  116900694
# 28                 Lee Daniels  PG-13      132  2013-08-16  116632095
# 29               Todd Phillips      R      100  2013-05-23  112200072
# ..                         ...    ...      ...         ...        ...
# 70             Ruben Fleischer      R      113  2013-01-11   46000903
# 71                         NaN  PG-13      127  2013-04-05   45385935
# 72                  Shawn Levy  PG-13      119  2013-06-07   44672764
# 73                         NaN  PG-13      115  2013-08-30   44467206
# 74             Ric Roman Waugh  PG-13      112  2013-02-22   42930462
# 75                 David Twohy      R      119  2013-09-06   42025135
# 76              Michael Tiddes      R       80  2013-01-11   40041683
# 77                 Carl Rinsch  PG-13      127  2013-12-25   38362475
# 78                  John Wells      R      130  2013-12-27   37738810
# 79              Stephen Frears  PG-13       95  2013-11-22   37709979
# 80                  Luc Besson      R      112  2013-09-13   36918811
# 81  Barry CookNeil Nightingale     PG       87  2013-12-20   36076121
# 82             Kimberly Peirce      R       92  2013-10-18   35266619
# 83             John Luessenhop      R       92  2013-01-04   34341945
# 84            Robert Schwentke  PG-13       96  2013-07-19   33618855
# 85                 Woody Allen  PG-13       98  2013-07-26   33405481
# 86                         NaN      R       75  2013-07-03   32244051
# 87           Steven Soderbergh      R      106  2013-02-08   32172757
# 88              Malcolm D. Lee  PG-13       85  2013-04-12   32015787
# 89                Harald Zwart  PG-13      120  2013-08-21   31165421
# 90                   Ken Scott  PG-13      105  2013-11-22   30664106
# 91                 Peter Segal  PG-13      113  2013-12-25   29807260
# 92             Morgan Spurlock     PG       92  2013-08-30   28873374
# 93                 Jeff Wadlow      R      103  2013-08-16   28795985
# 94            Jean-Marc Vallee      R      117  2013-11-01   27298285
# 95                  Ron Howard      R      123  2013-09-20   26947624
# 96               Andrew Niccol  PG-13      125  2013-03-29   26627201
# 97                Edgar Wright      R      109  2013-08-23   26004851
# 98        Jon LucasScott Moore      R       93  2013-03-01   25682380
# 99                 Spike Jonze      R      120  2013-12-18   25568251
#
#     m_budget  gross_in_millions
# 0      130.0         424.668047
# 1      200.0         409.013994
# 2      150.0         400.738009
# 3       76.0         368.061265
# 4      225.0         291.045518
# 5      100.0         274.092705
# 6        NaN         268.492764
# 7        NaN         258.366855
# 8      160.0         238.679850
# 9      215.0         234.911825
# 10     190.0         228.778661
# 11     170.0         206.362140
# 12     190.0         202.359711
# 13     135.0         187.168425
# 14      43.0         159.582188
# 15      37.0         150.394119
# 16      40.0         150.117807
# 17     105.0         144.840419
# 18      20.0         137.400141
# 19      35.0         134.506920
# 20      80.0         133.668525
# 21     120.0         132.556852
# 22      50.0         125.168368
# 23      40.0         125.095601
# 24     130.0         122.523060
# 25      78.0         119.793567
# 26      75.0         117.723989
# 27     100.0         116.900694
# 28      30.0         116.632095
# 29     103.0         112.200072
# ..       ...                ...
# 70      60.0          46.000903
# 71      10.0          45.385935
# 72      58.0          44.672764
# 73       NaN          44.467206
# 74       NaN          42.930462
# 75      38.0          42.025135
# 76       2.5          40.041683
# 77     175.0          38.362475
# 78       NaN          37.738810
# 79      12.0          37.709979
# 80      30.0          36.918811
# 81      80.0          36.076121
# 82      30.0          35.266619
# 83       NaN          34.341945
# 84     130.0          33.618855
# 85       NaN          33.405481
# 86       NaN          32.244051
# 87       NaN          32.172757
# 88      20.0          32.015787
# 89      60.0          31.165421
# 90      26.0          30.664106
# 91      40.0          29.807260
# 92      10.0          28.873374
# 93      28.0          28.795985
# 94       5.0          27.298285
# 95      38.0          26.947624
# 96      40.0          26.627201
# 97      20.0          26.004851
# 98      13.0          25.682380
# 99      23.0          25.568251
#
# [100 rows x 9 columns]>

# %%
df.groupby(['rating']).plot( x= 'releasedate', y = 'gross_in_millions',\
                            subplots=True, figsize=(6, 6));
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:2918: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=735040.0, right=735040.0
#   'left=%s, right=%s') % (left, right))

# %% [markdown]
# **Challenge 5**
#
# What director in your dataset has the highest gross per movie?

# %%
df_max = df.groupby(['director'])[['gross_in_millions']].mean().\
            sort_values('gross_in_millions',ascending = False)
df_max.iloc[0]
# Out:
# gross_in_millions    424.668047
# Name: Francis Lawrence, dtype: float64

# %% [markdown]
# **Challenge 6**
#
# Bin your dataset into months and make
# a bar graph of the mean domestic total
# gross by month. Error bars will represent
# the standard error of the mean.

# %%
df = df.set_index('releasedate')

# %%
sd =df.groupby(pd.Grouper(freq='M')).gross_in_millions.sem()

df.groupby(pd.Grouper(freq='M')).gross_in_millions.\
    mean().plot(kind='bar', yerr=sd)
